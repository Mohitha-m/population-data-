# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohitha-m/population-data-/blob/main/task1a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# !pip install wbgapi

# %%
import wbgapi as wb
import pandas as pd

# %%
df = pd.read_csv("/content/Metadata_Country_API_SP.POP.TOTL_DS2_en_csv_v2_900.csv", skiprows=4)

# %%
df
# Out:
#      AFW                  Unnamed: 1           Unnamed: 2  \
# 0    AGO          Sub-Saharan Africa  Lower middle income
# 1    ALB       Europe & Central Asia  Upper middle income
# 2    AND       Europe & Central Asia          High income
# 3    ARB                         NaN                  NaN
# 4    ARE  Middle East & North Africa          High income
# ..   ...                         ...                  ...
# 256  XKX       Europe & Central Asia  Upper middle income
# 257  YEM  Middle East & North Africa           Low income
# 258  ZAF          Sub-Saharan Africa  Upper middle income
# 259  ZMB          Sub-Saharan Africa  Lower middle income
# 260  ZWE          Sub-Saharan Africa  Lower middle income
#
#     22 countries, stretching from the westernmost point of Africa, across the equator, and partly along the Atlantic Ocean till the Republic of Congo in the South (https://www.worldbank.org/en/region/afr/western-and-central-africa)  \
# ...

# %%
df = df.rename(columns={"Unnamed: 1": "Region","AFW": "Country Code","22 countries, stretching from the westernmost point of Africa, across the equator, and partly along the Atlantic Ocean till the Republic of Congo in the South (https://www.worldbank.org/en/region/afr/western-and-central-africa)": "SpecialNotes","Unnamed: 2": "IncomeGroup","Africa Western and Central": "TableName"})

# %%
df
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            AGO          Sub-Saharan Africa  Lower middle income
# 1            ALB       Europe & Central Asia  Upper middle income
# 2            AND       Europe & Central Asia          High income
# 3            ARB                         NaN                  NaN
# 4            ARE  Middle East & North Africa          High income
# ..           ...                         ...                  ...
# 256          XKX       Europe & Central Asia  Upper middle income
# 257          YEM  Middle East & North Africa           Low income
# 258          ZAF          Sub-Saharan Africa  Upper middle income
# 259          ZMB          Sub-Saharan Africa  Lower middle income
# 260          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes             TableName  \
# 0    The World Bank systematically assesses the app...                Angola
# ...

# %%
gender_counts = df['Region'].value_counts()
bar_width = 0.9
x=range(len(gender_counts.index))


plt.bar(gender_counts.index,gender_counts.values)
plt.xlabel('Region')
plt.ylabel('Count')
plt.title('Distribution of Region')


plt.xticks(x,gender_counts.index,rotation=45)
plt.tight_layout()
plt.show()

# %%
df.shape
# Out:
# (261, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Code  261 non-null    object
#  1   Region        215 non-null    object
#  2   IncomeGroup   214 non-null    object
#  3   SpecialNotes  124 non-null    object
#  4   TableName     261 non-null    object
#  5   Unnamed: 5    0 non-null      float64
# dtypes: float64(1), object(5)
# memory usage: 12.4+ KB

# %%
df.describe()
# Out:
#        Unnamed: 5
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
df.isnull().sum()
# Out:
# Country Code      0
# Region           46
# IncomeGroup      47
# SpecialNotes    137
# TableName         0
# Unnamed: 5      261
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Code  261 non-null    object
#  1   Region        215 non-null    object
#  2   IncomeGroup   214 non-null    object
#  3   SpecialNotes  124 non-null    object
#  4   TableName     261 non-null    object
#  5   Unnamed: 5    0 non-null      float64
# dtypes: float64(1), object(5)
# memory usage: 12.4+ KB
